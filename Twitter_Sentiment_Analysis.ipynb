# %% [markdown]
# <a href="https://colab.research.google.com/github/RedHotChiliPeppers35/Twitter-Sentiment-Analysis/blob/main/Twitter_Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install transformers datasets torch scikit-learn pandas

# %%
from transformers import pipeline

# %%
sentiment = pipeline("sentiment-analysis")

# %%
print(sentiment("I love this sunny Fridays"))
print(sentiment("I love this phone! It's amazing."))
print(sentiment("This is the worst thing I've ever bought."))

# %%
pip install transformers torch pandas
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.52.4)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.32.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (1.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.4.26)

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from scipy.special import softmax
import torch
import pandas as pd

# %%
MODEL = "cardiffnlp/twitter-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)
# Out:
# config.json:   0%|          | 0.00/747 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/499M [00:00<?, ?B/s]

# %%
def analyze_sentiment(text):
    # Preprocessing
    encoded_input = tokenizer(text, return_tensors='pt', truncation=True)
    with torch.no_grad():
        output = model(**encoded_input)
    scores = output.logits[0].numpy()
    scores = softmax(scores)  # Normalize to probabilities

    labels = ['negative', 'neutral', 'positive']
    sentiment = {label: float(score) for label, score in zip(labels, scores)}
    return max(sentiment, key=sentiment.get)  # return the label with highest score

# %%
import tweepy
import pandas as pd

# Set your Bearer Token here
bearer_token = 'AAAAAAAAAAAAAAAAAAAAAFO01wEAAAAA6xseG4lxaVqFAmjhnf1ap5lLYZw%3D3S6HaJ3Nzwi0XAYl8wDbjKnzxCIfbhlSo4DrmkgDNtHOXO4sLG'

# Authenticate
client = tweepy.Client(bearer_token=bearer_token)

# Define query parameters
query = 'iPhone -is:retweet lang:en'  # search tweets about "iPhone" in English

# Get recent tweets
tweets = client.search_recent_tweets(query=query, max_results=50)

# Parse tweets
tweet_texts = [tweet.text for tweet in tweets.data]

# Convert to DataFrame
df = pd.DataFrame(tweet_texts, columns=["tweet"])
print(df.head())
# Out:
#                                                tweet
# 0  @SpotifyCares I already spoke to one of your a...
# 1  OPENBOX IPHONE 16\n98%BH\n128GB\nPHYSICAL +ESI...
# 2  that phone looks like an iphone knockoffs with...
# 3  I don sell my iphone take guide.I no fit dey u...
# 4  AND!!!! the naqabi girl has a friend who's bee...

# %%
newdf = df["tweet"]
print(newdf)
# Out:
# 0     @SpotifyCares I already spoke to one of your a...
# 1     OPENBOX IPHONE 16\n98%BH\n128GB\nPHYSICAL +ESI...
# 2     that phone looks like an iphone knockoffs with...
# 3     I don sell my iphone take guide.I no fit dey u...
# 4     AND!!!! the naqabi girl has a friend who's bee...
# 5     Lost my phone in a coffee shop Anyone seen a b...
# 6     @official_maxiee Some people don't focus on li...
# 7     😭 ‘’’experiene’’ a film on your iphone…\nwtf a...
# 8     @Fosudo iOS 26 "liquid glass" on iPhone is bas...
# 9     @imPatrickT Was able to experience it on my iP...
# 10    Life's so private nobody knew I won iPhone 13 ...
# 11    getting annual zoo membership so expect to see...
# 12    @_ChasinChecks @KollegeKidd You’re proving his...
# 13    @1973Jtizz @JV_Hund @The_TUC Neither do you, t...
# 14    @MichaelJLev According to my iPhone weather ap...
# 15    @meamZ_DE @MilfeulleSakura @JakeKarll @tritlo ...
# 16    @abazwhyllzz Or iPhone has jointly been copyin...
# 17    My iPhone has nicely labeled my two surgeries ...
# 18    @_ChasinChecks @KollegeKidd All iPhone does is...
# 19    @lewdismug even with good eyesight i always di...
# 20    WHAT KIND OF IPHONE DO U HAVE 😭😭😭😭😭😭 https://t...
# 21    @abazwhyllzz Techno keeps copying iphone while...
# 22    Only five iPhones available iPhones are $100‼️...
# 23    @lichtparfait You can’t emulate shit on an iPh...
# 24    @notpythonn @BarcaTimes Such an ungrateful kid...
# 25    anybody who have an iphone 11 dont need to upd...
# 26    @abazwhyllzz What brand of tecno is that? Aski...
# 27    They’ve sold fake iPhone charger to me again😭😭...
# 28    iPhone 17 Series to Feature High Refresh Rate ...
# 29    JAKE KELLIE ANNOUNCES NEW ROLE 🔥 One of the Ba...
# 30    @likhithakoppula @Apple yea i’m prolly gna buy...
# 31    @Trey_Explainer They're minding their business...
# 32                            @Bigwavee00 iPhone 16 sir
# 33    📢 Get NetSpot 3.1 for #iPhone🚀 with Device Dis...
# 34    Apple have a secret phone recycling plant in t...
# 35    @LyfeOfRyley Thanks girly! Just with my iPhone...
# 36    "Still don’t understand how people with no job...
# 37    Comparing Cameras, iPhone 14 Plus, Sony Xperia...
# 38    This is so cool on iPhone 😱🤪❤️ https://t.co/ZZ...
# 39    @abazwhyllzz Abeg Make dem try make am same si...
# 40    @NNBLBlog @garykoepnick @RealMattCouch Here’s ...
# 41    @yogesh_gosavi_ It’s very nice!\nToo bad I use...
# 42    Amazon Prime: https://t.co/tT4tfP4nYQ  Meditat...
# 43    Lost my phone in a coffee shop Anyone seen a s...
# 44    @masendi_sunday @applesclubs 6-7 years support...
# 45    @occupyheaven777 Bin the iphone then. They are...
# 46                  @dunniswago It’s an iPhone, we know
# 47    im convinced this update only exists to furthe...
# 48    Get my art printed on awesome products. Suppor...
# 49    @jessy_kween Dash me your old one and before m...
# Name: tweet, dtype: object

# %%
list_of_tweets = newdf.tolist()

# %%
results = [analyze_sentiment(tweet) for tweet in list_of_tweets]

# %%
df = pd.DataFrame({'tweet': list_of_tweets, 'sentiment': results})
print(df)
# Out:
#                                                 tweet sentiment
# 0   @SpotifyCares I already spoke to one of your a...  negative
# 1   OPENBOX IPHONE 16\n98%BH\n128GB\nPHYSICAL +ESI...   neutral
# 2   that phone looks like an iphone knockoffs with...   neutral
# 3   I don sell my iphone take guide.I no fit dey u...  negative
# 4   AND!!!! the naqabi girl has a friend who's bee...  negative
# 5   Lost my phone in a coffee shop Anyone seen a b...  negative
# 6   @official_maxiee Some people don't focus on li...  negative
# 7   😭 ‘’’experiene’’ a film on your iphone…\nwtf a...  negative
# 8   @Fosudo iOS 26 "liquid glass" on iPhone is bas...   neutral
# 9   @imPatrickT Was able to experience it on my iP...  positive
# 10  Life's so private nobody knew I won iPhone 13 ...  negative
# 11  getting annual zoo membership so expect to see...   neutral
# 12  @_ChasinChecks @KollegeKidd You’re proving his...  negative
# 13  @1973Jtizz @JV_Hund @The_TUC Neither do you, t...  negative
# 14  @MichaelJLev According to my iPhone weather ap...   neutral
# 15  @meamZ_DE @MilfeulleSakura @JakeKarll @tritlo ...  negative
# 16  @abazwhyllzz Or iPhone has jointly been copyin...   neutral
# 17  My iPhone has nicely labeled my two surgeries ...   neutral
# 18  @_ChasinChecks @KollegeKidd All iPhone does is...   neutral
# 19  @lewdismug even with good eyesight i always di...  negative
# 20  WHAT KIND OF IPHONE DO U HAVE 😭😭😭😭😭😭 https://t...  negative
# 21  @abazwhyllzz Techno keeps copying iphone while...   neutral
# 22  Only five iPhones available iPhones are $100‼️...  positive
# 23  @lichtparfait You can’t emulate shit on an iPh...  negative
# 24  @notpythonn @BarcaTimes Such an ungrateful kid...  negative
# 25  anybody who have an iphone 11 dont need to upd...  negative
# 26  @abazwhyllzz What brand of tecno is that? Aski...  negative
# 27  They’ve sold fake iPhone charger to me again😭😭...  negative
# 28  iPhone 17 Series to Feature High Refresh Rate ...  positive
# 29  JAKE KELLIE ANNOUNCES NEW ROLE 🔥 One of the Ba...  positive
# 30  @likhithakoppula @Apple yea i’m prolly gna buy...  positive
# 31  @Trey_Explainer They're minding their business...   neutral
# 32                          @Bigwavee00 iPhone 16 sir   neutral
# 33  📢 Get NetSpot 3.1 for #iPhone🚀 with Device Dis...  positive
# 34  Apple have a secret phone recycling plant in t...  positive
# 35  @LyfeOfRyley Thanks girly! Just with my iPhone...  positive
# 36  "Still don’t understand how people with no job...  negative
# 37  Comparing Cameras, iPhone 14 Plus, Sony Xperia...   neutral
# 38  This is so cool on iPhone 😱🤪❤️ https://t.co/ZZ...  positive
# 39  @abazwhyllzz Abeg Make dem try make am same si...   neutral
# 40  @NNBLBlog @garykoepnick @RealMattCouch Here’s ...   neutral
# 41  @yogesh_gosavi_ It’s very nice!\nToo bad I use...  positive
# 42  Amazon Prime: https://t.co/tT4tfP4nYQ  Meditat...  positive
# 43  Lost my phone in a coffee shop Anyone seen a s...  negative
# 44  @masendi_sunday @applesclubs 6-7 years support...  positive
# 45  @occupyheaven777 Bin the iphone then. They are...  negative
# 46                @dunniswago It’s an iPhone, we know   neutral
# 47  im convinced this update only exists to furthe...   neutral
# 48  Get my art printed on awesome products. Suppor...  positive
# 49  @jessy_kween Dash me your old one and before m...   neutral
